# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import kalman_filters as kf

A_cont = np.array([[0, 1, 0],
                   [0, 0, 1],
                   [0, 0, 0]])

C = np.array([[1, 0, 0]])

Rt = np.diag([6, 0, .005])

Qt = np.array([[2]])

x = np.array([[500], [0], [0]])


time, x_list, z_list = kf.create_synthetic_data(A_cont, C, Rt, Qt, x, num_samples=1000)
kf.kalman_josh_main(A_cont, C, Rt, Qt, time, z_list)
